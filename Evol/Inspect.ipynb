# %%
import sys
print sys.path

from e_net import e_net
from inspect import fetch_internal
p = './Result/<8-10:17:45>TEST[E50]/[ACC-0.77129 E48]'
e = 48
net = e_net()
from load_e import get
out = get(2, small=True)
data = out['train']
outputs, imgs, lls = fetch_internal(net, data, p, e)
# Out:
# ['', '/usr/local/lib/python2.7/dist-packages/mock-1.0.1-py2.7.egg', '/usr/local/lib/python2.7/dist-packages/easydict-1.6-py2.7.egg', '/usr/local/lib/python2.7/dist-packages/enum-0.4.6-py2.7.egg', '/home/jialin/gym', '/home/zijia/minpy/python', '/home/zijia/caffe_FCN/python', '/home/zijia/mxnet/python', '/home/zijia', '/home/zijia/HeartDeepLearning', '/home/zijia/HeartDeepLearning/Evol', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/usr/lib/python2.7/lib-old', '/usr/lib/python2.7/lib-dynload', '/usr/local/lib/python2.7/dist-packages', '/usr/local/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages/PILcompat', '/usr/lib/python2.7/dist-packages/gtk-2.0', '/usr/lib/pymodules/python2.7', '/usr/lib/python2.7/dist-packages/ubuntu-sso-client', '/usr/local/lib/python2.7/dist-packages/IPython/extensions', '/home/zijia/.ipython', '/home/zijia/mxnet-myfork/mxnet/python/']
# ...

# %%
import my_utils as mu
# %matplotlib inline
for k, v in outputs.items():
    if k.startswith('c'):
        print k, v.shape, v[0,0].mean()
        mu.show(v[0,0])
# Out:
# c3_3 (84, 1, 64, 64) -14.0957
# c3_2 (84, 16, 64, 64) 2.47482
# c3_1 (84, 64, 64, 64) -23.0803
# c2_2 (84, 64, 128, 128) -50.9286
# c2_3 (84, 64, 128, 128) -0.0238347
# c2_1 (84, 64, 128, 128) -0.132417
# concat1 (84, 129, 128, 128) 0.362108
# concat0 (84, 65, 128, 128) 0.376703
# c1_1 (84, 32, 256, 256) -1.00068
# c1_3 (84, 64, 256, 256) 0.327821
# c1_2 (84, 32, 256, 256) -140.674

# %%
pred = outputs['softmax']
print pred.shape
print pred.mean(axis=(1,2,3))
for i in pred:
    mu.show(i[0])
# Out:
# (84, 1, 64, 64)
# [ 0.09340348  0.07037529  0.08513999  0.07865058  0.1071284   0.05966512
#   0.05432956  0.12727928  0.05289669  0.06541674  0.05421397  0.07548387
#   0.04446381  0.06038112  0.05499671  0.03641893  0.05334233  0.07552321
#   0.05124902  0.06340282  0.0441296   0.08362663  0.07678048  0.08860447
#   0.07443854  0.06457597  0.072944    0.0549019   0.10404164  0.0347981
#   0.05175648  0.06641956  0.07224413  0.09446412  0.03199845  0.1065792
#   0.07037579  0.04707463  0.0955876   0.07803352  0.06400739  0.10430603
#   0.07487182  0.0736226   0.05833983  0.05700091  0.06327513  0.12823674
#   0.04025362  0.07732128  0.05595186  0.10782417  0.06474413  0.06541657
#   0.07480805  0.06435938  0.06860311  0.04489733  0.05803044  0.0390067
#   0.05470645  0.05180105  0.10744435  0.06950746  0.08587642  0.05382111
#   0.12392356  0.05920263  0.07368323  0.05366994  0.06952757  0.07260551
#   0.06105974  0.08194072  0.04053622  0.05886104  0.0435003   0.07351011
# ...
