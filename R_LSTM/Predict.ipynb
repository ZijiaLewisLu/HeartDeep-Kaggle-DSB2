# %%
import ipt
import mxnet as mx
import my_utils as mu
# %matplotlib inline

# %%
files = ['../DATA/PK/patience/SC-HF-I-2.pk']

from RNN.rnn_load import load_rnn_pk
imgs, labels = load_rnn_pk(files)
print imgs.shape, labels.shape
# Out:
# Substract Mean
# (1, 260, 1, 256, 256) (1, 260, 1, 256, 256)

# %%
from r_lstm import R_LSTM_Iter
val = R_LSTM_Iter(imgs[:,:100], label=labels[:,:100], num_hidden=3)

from solver import Solver
from train import make_net
from settings import PARAMS, SOLVE
from RNN.rnn_feed import Feed

model = Feed.load('./Result/<26-12:43:22>[E5]/[ACC-0.97747 E4]', 4, ctx=mu.gpu(1))
out = mu.predict_draw(model, val, draw=False)

# %%
P,I,L = out[0][0][0], out[1][0], out[2][0]
print I.shape, L.shape
import matplotlib.pyplot as plt

LEN = P.shape[0]

for i in range(LEN):
    fig, subs = plt.subplots(1,3)
    subs[0].imshow(P[i])
    subs[1].imshow(I[i])
    subs[2].imshow(L[i])
    plt.show()
    plt.close(fig)
# Out:
# (100, 256, 256) (100, 256, 256)
